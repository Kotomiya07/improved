# %%
import argparse
import os
import shutil

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torch.utils.data import Dataset, DataLoader
from datasets_prep.dataset import create_dataset
from diffusion import sample_from_model, sample_posterior, \
    q_sample_pairs, get_time_schedule, \
    Posterior_Coefficients, Diffusion_Coefficients
#from DWT_IDWT.DWT_IDWT_layer import DWT_2D, IDWT_2D
#from pytorch_wavelets import DWTForward, DWTInverse
from torch.multiprocessing import Process
from utils import init_processes, copy_source, broadcast_params, save_image
import yaml

from ldm.util import instantiate_from_config
from omegaconf import OmegaConf
import wandb
from diffusers.models import AutoencoderKL

def load_model_from_config(config_path, ckpt):
    print(f"Loading model from {ckpt}")
    config = OmegaConf.load(config_path)
    pl_sd = torch.load(ckpt, map_location="cpu")
    #global_step = pl_sd["global_step"]
    sd = pl_sd["state_dict"]
    model = instantiate_from_config(config.model)
    m, u = model.load_state_dict(sd, strict=False)
    model = model.first_stage_model
    model.cuda()
    model.eval()
    del m
    del u
    del pl_sd
    return model

def grad_penalty_call(args, D_real, x_t):
    grad_real = torch.autograd.grad(
        outputs=D_real.sum(), inputs=x_t, create_graph=True
    )[0]
    grad_penalty = (
        grad_real.view(grad_real.size(0), -1).norm(2, dim=1) ** 2
    ).mean()

    grad_penalty = args.r1_gamma / 2 * grad_penalty
    grad_penalty.backward()

class CustomDataset(Dataset):
    def __init__(self, features_dir, labels_dir):
        self.features_dir = features_dir
        self.labels_dir = labels_dir

        self.features_files = sorted(os.listdir(features_dir))
        self.labels_files = sorted(os.listdir(labels_dir))

    def __len__(self):
        assert len(self.features_files) == len(self.labels_files), \
            "Number of feature files and label files should be same"
        return len(self.features_files)

    def __getitem__(self, idx):
        feature_file = self.features_files[idx]
        label_file = self.labels_files[idx]

        features = np.load(os.path.join(self.features_dir, feature_file))
        labels = np.load(os.path.join(self.labels_dir, label_file))
        return torch.from_numpy(features), torch.from_numpy(labels)

# %%
from get_args import get_args
args = [
    "--dataset", "afhq_cat", "--image_size", "64",
    "--exp", "test", "--num_channels", "4",
    "--num_channels_dae", "128", "--ch_mult", "1", "2", "2", "2", 
    "--num_timesteps", "2", "--num_res_blocks", "2", 
    "--batch_size", "32", "--num_epoch", "200", 
    "--ngf", "64", "--embedding_type", "positional", 
    "--use_ema", "--ema_decay", "0.999",
    "--r1_gamma", "1.", "--nz", "100",
    "--z_emb_dim", "256", "--lr_d", "1.0e-4",
    "--lr_g", "2e-4", "--lazy_reg", "10",
    "--save_content", "--datadir", "data/afhq", 
    "--master_port", "6084", "--num_process_per_node", "0",
    "--current_resolution", "32", "--attn_resolution", "16",
    "--num_disc_layers", "4", "--rec_loss", 
    "--save_content_every", "1", "--AutoEncoder_config", "./autoencoder/config/kl-f2.yaml", 
    "--AutoEncoder_ckpt", "./autoencoder/weight/kl-f2.ckpt", "--scale_factor", "6.0", 
    "--no_lr_decay", "--sigmoid_learning",
    "--scale_factor", "1",
]

args = get_args(args)

# %%
from EMA import EMA
from score_sde.models.discriminator import Discriminator_large, Discriminator_small
from score_sde.models.ncsnpp_generator_adagn import NCSNpp, WaveletNCSNpp

rank = 0
gpu = 0

torch.manual_seed(args.seed + rank)
torch.cuda.manual_seed(args.seed + rank)
torch.cuda.manual_seed_all(args.seed + rank)
device = torch.device('cuda:{}'.format(gpu))

batch_size = args.batch_size

nz = args.nz  # latent dimension

#latent_size = args.image_size // 8

dataset = create_dataset(args)

#features_dir = f"{args.feature_path}/{args.dataset}/{args.image_size}_features"
#labels_dir = f"{args.feature_path}/{args.dataset}/{args.image_size}_labels"
#dataset = CustomDataset(features_dir, labels_dir)

#train_sampler = torch.utils.data.distributed.DistributedSampler(dataset,
#                                                                num_replicas=args.world_size,
#                                                                rank=rank)
data_loader = DataLoader(dataset,
                        batch_size=batch_size,
                        shuffle=False,
                        num_workers=args.num_workers,
                        pin_memory=True,
                        drop_last=True)
args.ori_image_size = args.image_size
args.image_size = args.current_resolution
G_NET_ZOO = {"normal": NCSNpp, "wavelet": WaveletNCSNpp}
gen_net = G_NET_ZOO[args.net_type]
disc_net = [Discriminator_small, Discriminator_large]
print("GEN: {}, DISC: {}".format(gen_net, disc_net))
netG = gen_net(args).to(device)

if args.dataset in ['cifar10', 'stl10', 'afhq_cat']:
    netD = disc_net[0](nc=2 * args.num_channels, ngf=args.ngf,
                       t_emb_dim=args.t_emb_dim,
                       act=nn.LeakyReLU(0.2), num_layers=args.num_disc_layers).to(device)
else:
    netD = disc_net[1](nc=2 * args.num_channels, ngf=args.ngf,
                       t_emb_dim=args.t_emb_dim,
                       act=nn.LeakyReLU(0.2), num_layers=args.num_disc_layers).to(device)

#broadcast_params(netG.parameters())
#broadcast_params(netD.parameters())

optimizerD = optim.Adam(filter(lambda p: p.requires_grad, netD.parameters(
)), lr=args.lr_d, betas=(args.beta1, args.beta2))
optimizerG = optim.Adam(filter(lambda p: p.requires_grad, netG.parameters(
)), lr=args.lr_g, betas=(args.beta1, args.beta2))

if args.use_ema:
    optimizerG = EMA(optimizerG, ema_decay=args.ema_decay)

schedulerG = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizerG, args.num_epoch, eta_min=1e-5)
schedulerD = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizerD, args.num_epoch, eta_min=1e-5)

# ddp
#netG = nn.parallel.DistributedDataParallel(
#    netG, device_ids=[gpu], find_unused_parameters=True)
#netD = nn.parallel.DistributedDataParallel(netD, device_ids=[gpu])

"""############### DELETE TO AVOID ERROR ###############"""
# Wavelet Pooling
#if not args.use_pytorch_wavelet:
#    dwt = DWT_2D("haar")
#    iwt = IDWT_2D("haar")
#else:
#    dwt = DWTForward(J=1, mode='zero', wave='haar').cuda()
#    iwt = DWTInverse(mode='zero', wave='haar').cuda()
    

#load encoder and decoder
config_path = args.AutoEncoder_config 
ckpt_path = args.AutoEncoder_ckpt 

if args.dataset in ['cifar10', 'stl10', 'coco', 'afhq_cat']:
    with open(config_path, 'r') as file:
        config = yaml.safe_load(file)
    
    AutoEncoder = instantiate_from_config(config['model'])
    

    checkpoint = torch.load(ckpt_path, map_location=device)
    AutoEncoder.load_state_dict(checkpoint['state_dict'])
    AutoEncoder.eval()
    AutoEncoder.to(device)

#else:
#    AutoEncoder = load_model_from_config(config_path, ckpt_path)
"""############### END DELETING ###############"""

#AutoEncoder = AutoencoderKL.from_pretrained(f"stabilityai/sd-vae-ft-{args.vae}").to(device)

#num_levels = int(np.log2(args.ori_image_size // args.current_resolution))

exp = args.exp
parent_dir = "./saved_info/{}".format(args.dataset)

exp_path = os.path.join(parent_dir, exp)
if rank == 0:
    if not os.path.exists(exp_path):
        os.makedirs(exp_path)
        copy_source(__file__, exp_path)
        shutil.copytree('score_sde/models', os.path.join(exp_path, 'score_sde/models'))

coeff = Diffusion_Coefficients(args, device)
pos_coeff = Posterior_Coefficients(args, device)
T = get_time_schedule(args, device)

if args.resume or os.path.exists(os.path.join(exp_path, 'content.pth')):
    checkpoint_file = os.path.join(exp_path, 'content.pth')
    checkpoint = torch.load(checkpoint_file, map_location=device)
    init_epoch = checkpoint['epoch']
    epoch = init_epoch
    # load G
    netG.load_state_dict(checkpoint['netG_dict'])
    #optimizerG.load_state_dict(checkpoint['optimizerG'])
    schedulerG.load_state_dict(checkpoint['schedulerG'])
    # load D
    netD.load_state_dict(checkpoint['netD_dict'])
    #optimizerD.load_state_dict(checkpoint['optimizerD'])
    schedulerD.load_state_dict(checkpoint['schedulerD'])

    global_step = checkpoint['global_step']
    print("=> loaded checkpoint (epoch {})"
          .format(checkpoint['epoch']))
else:
    global_step, epoch, init_epoch = 0, 0, 0

'''Sigmoid learning parameter'''
gamma = 6
beta = np.linspace(-gamma, gamma, args.num_epoch+1)
alpha = 1 - 1 / (1+np.exp(-beta))

if args.dataset in ['cifar10'] and args.class_conditional:
    class_embedding = nn.Embedding(10, nz).to(device)

nrow = 2
if args.batch_size >= 5:
    nrow = 3
if args.batch_size >= 10:
    nrow = 10
# Out:
# /scratch/users/std/2021/21k0005/improved-ddgan/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# GEN: <class 'score_sde.models.ncsnpp_generator_adagn.NCSNpp'>, DISC: [<class 'score_sde.models.discriminator.Discriminator_small'>, <class 'score_sde.models.discriminator.Discriminator_large'>]
# making attention of type 'vanilla' with 256 in_channels
# making attention of type 'vanilla' with 256 in_channels
# making attention of type 'vanilla' with 256 in_channels
# Working with z of shape (1, 4, 16, 16) = 1024 dimensions.
# making attention of type 'vanilla' with 256 in_channels
# making attention of type 'vanilla' with 256 in_channels
# making attention of type 'vanilla' with 256 in_channels
# making attention of type 'vanilla' with 256 in_channels
# /scratch/users/std/2021/21k0005/improved-ddgan/.venv/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /scratch/users/std/2021/21k0005/improved-ddgan/.venv/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# loaded pretrained LPIPS loss from taming/modules/autoencoder/lpips/vgg.pth

# %%
tmp = iter(data_loader)
x, y = next(tmp)
# Out:
# /scratch/users/std/2021/21k0005/improved-ddgan/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
x.shape
# Out:
# torch.Size([32, 3, 64, 64])

# %%
import matplotlib.pyplot as plt
from torchvision import transforms
from IPython.display import display
from PIL import Image

grid_img = torchvision.utils.make_grid(x)

# TensorをPIL画像に変換して保存
ndarr = grid_img.mul(255).clamp(0, 255).byte().permute(1, 2, 0).cpu().numpy()
im = Image.fromarray(ndarr)
display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=530x266>

# %%
from PIL import Image
MEAN = [[0.5, 0.5, 0.5],[0.3053, 0.2815, 0.2438]]
STD  = [[0.5, 0.5, 0.5],[0.1789, 0.1567, 0.1587]]

def denormalize(tensor, mean, std):
    # meanとstdをtensorの形に合わせて調整
    mean = torch.tensor(mean).view(1, 3, 1, 1)
    std = torch.tensor(std).view(1, 3, 1, 1)
    # データを逆正規化
    tensor = tensor * std + mean
    return tensor

# バッチを逆正規化
denorm_batch = denormalize(x, MEAN[0], STD[0])
# torchvision.utils.make_gridでバッチをグリッド画像に変換
grid_img = torchvision.utils.make_grid(denorm_batch)

# TensorをPIL画像に変換して保存
ndarr = grid_img.mul(255).clamp(0, 255).byte().permute(1, 2, 0).cpu().numpy()
im = Image.fromarray(ndarr)
im.save('output_image.png')
display(im)
# Out:
# <PIL.Image.Image image mode=RGB size=530x266>

# %%
for epoch in range(init_epoch, args.num_epoch + 1):
    #train_sampler.set_epoch(epoch)
    
    start = torch.cuda.Event(enable_timing=True)
    end = torch.cuda.Event(enable_timing=True)
    start.record()

    start_epoch = torch.cuda.Event(enable_timing=True)
    end_epoch = torch.cuda.Event(enable_timing=True)
    start_epoch.record()
    for iteration, (x, y) in enumerate(data_loader):
        for p in netD.parameters():
            p.requires_grad = True
        netD.zero_grad()

        for p in netG.parameters():
            p.requires_grad = False

        # sample from p(x_0)
        x0 = x.to(device, non_blocking=True)
        #x0 = x0.squeeze(dim=1)

        """################# Change here: Encoder #################"""
        with torch.no_grad():
            posterior = AutoEncoder.encode(x0)
            real_data = posterior.sample().detach()
        #print("MIN:{}, MAX:{}".format(real_data.min(), real_data.max()))
        #print(f'{args.scale_factor=}')
        #real_data = real_data / args.scale_factor #300.0  # [-1, 1]
        #real_data = x0
        #assert -1 <= real_data.min() < 0
        #assert 0 < real_data.max() <= 1
        """################# End change: Encoder #################"""
        # sample t
        t = torch.randint(0, args.num_timesteps,
                          (real_data.size(0),), device=device)
        
        if args.dataset in ['cifar10'] and args.class_conditional:
            y = y.to(device)
            y = y.squeeze(dim=1)
            y_emb = class_embedding(y)

        x_t, x_tp1 = q_sample_pairs(coeff, real_data, t)
        x_t.requires_grad = True

        """################# Save Sample #################"""
        """
        if iteration % 10 == 0:
            print(f"Epoch: {epoch}, Iteration: {iteration}")
        if iteration % 50 == 0:
            x_t_1 = torch.randn_like(posterior.sample())
            if args.dataset in ['cifar10'] and args.class_conditional:
                y = torch.arange(0, 10).repeat(x_t_1.size(0)//10 + 1)[:x_t_1.size(0)].to(device)
                y_emb = class_embedding(y)
                fake_sample = sample_from_model(
                    pos_coeff, netG, args.num_timesteps, x_t_1, T, args, class_emb=y_emb)
            else:
                fake_sample = sample_from_model(
                    pos_coeff, netG, args.num_timesteps, x_t_1, T, args)
            fake_sample *= args.scale_factor #300
            real_sample = real_data.detach().clone()

        save_image(fake_sample, real_data, AutoEncoder, exp_path, epoch, nrow)
        """

        # train with real
        D_real = netD(x_t, t, x_tp1.detach()).view(-1)
        errD_real = F.softplus(-D_real).mean()

        errD_real.backward(retain_graph=True)

        if args.lazy_reg is None:
            grad_penalty_call(args, D_real, x_t)
        else:
            if global_step % args.lazy_reg == 0:
                grad_penalty_call(args, D_real, x_t)

        # train with fake
        latent_z = torch.randn(batch_size, nz, device=device)
        if args.dataset in ['cifar10'] and args.class_conditional:
            x_0_predict = netG(x_tp1.detach(), t, torch.cat([latent_z, y_emb], dim=1).detach())
        else:
            x_0_predict = netG(x_tp1.detach(), t, latent_z)
        x_pos_sample = sample_posterior(pos_coeff, x_0_predict, x_tp1, t)

        output = netD(x_pos_sample, t, x_tp1.detach()).view(-1)
        errD_fake = F.softplus(output).mean()

        errD_fake.backward()

        errD = errD_real + errD_fake
        # Update D
        optimizerD.step()

        # update G
        for p in netD.parameters():
            p.requires_grad = False

        for p in netG.parameters():
            p.requires_grad = True
        netG.zero_grad()

        t = torch.randint(0, args.num_timesteps,
                          (real_data.size(0),), device=device)
        x_t, x_tp1 = q_sample_pairs(coeff, real_data, t)

        latent_z = torch.randn(batch_size, nz, device=device)
        if args.dataset in ['cifar10'] and args.class_conditional:
            x_0_predict = netG(x_tp1.detach(), t, torch.cat([latent_z, y_emb], dim=1).detach())
        else:
            x_0_predict = netG(x_tp1.detach(), t, latent_z)
        x_pos_sample = sample_posterior(pos_coeff, x_0_predict, x_tp1, t)

        output = netD(x_pos_sample, t, x_tp1.detach()).view(-1)
        errG = F.softplus(-output).mean()

        # reconstructior loss
        if args.sigmoid_learning and args.rec_loss:
            ######alpha
            rec_loss = F.l1_loss(x_0_predict, real_data)
            errG = errG + alpha[epoch]*rec_loss

        elif args.rec_loss and not args.sigmoid_learning:
            rec_loss = F.l1_loss(x_0_predict, real_data)
            errG = errG + rec_loss
        

        errG.backward()
        optimizerG.step()

        global_step += 1
        if iteration % 100 == 0:
            if rank == 0:
                end.record()
                torch.cuda.synchronize()
                elapsed_time = start.elapsed_time(end)
                if args.sigmoid_learning:
                    print('epoch {} iteration{}, G Loss: {}, D Loss: {}, alpha: {}'.format(
                        epoch, iteration, errG.item(), errD.item(), alpha[epoch]))
                elif args.rec_loss:
                    print('epoch {} iteration{}, G Loss: {}, D Loss: {}, rec_loss: {}'.format(
                        epoch, iteration, errG.item(), errD.item(), rec_loss.item()))
                else:   
                    print('epoch {} iteration{}, G Loss: {}, D Loss: {}'.format(
                        epoch, iteration, errG.item(), errD.item()))
                start = torch.cuda.Event(enable_timing=True)
                end = torch.cuda.Event(enable_timing=True)
                start.record()

    if not args.no_lr_decay:

        schedulerG.step()
        schedulerD.step()

    if rank == 0:
        end_epoch.record()
        torch.cuda.synchronize()
        time_per_epoch = start_epoch.elapsed_time(end_epoch)
        #wandb.log({"G_loss": errG.item(), "D_loss": errD.item(), "alpha": alpha[epoch], "time_per_epoch": time_per_epoch / 1000})
        ########################################
        x_t_1 = torch.randn_like(posterior.sample())
        if args.dataset in ['cifar10'] and args.class_conditional:
            y = torch.arange(0, 10).repeat(x_t_1.size(0)//10 + 1)[:x_t_1.size(0)].to(device)
            y_emb = class_embedding(y)
            fake_sample = sample_from_model(
                pos_coeff, netG, args.num_timesteps, x_t_1, T, args, class_emb=y_emb)
        else:
            fake_sample = sample_from_model(
                pos_coeff, netG, args.num_timesteps, x_t_1, T, args)

        """############## CHANGE HERE: DECODER ##############"""
        #fake_sample *= args.scale_factor #300
        #real_data *= args.scale_factor #300

        """##############SAVE IMAGE##############"""
        save_image(fake_sample, real_data, AutoEncoder, exp_path, epoch, nrow)

        if args.save_content:
            if epoch % args.save_content_every == 0:
                print('Saving content.')
                content = {'epoch': epoch + 1, 'global_step': global_step, 'args': args,
                           'netG_dict': netG.state_dict(), 'optimizerG': optimizerG.state_dict(),
                           'schedulerG': schedulerG.state_dict(), 'netD_dict': netD.state_dict(),
                           'optimizerD': optimizerD.state_dict(), 'schedulerD': schedulerD.state_dict()}
                torch.save(content, os.path.join(exp_path, 'content.pth'))

        if epoch % args.save_ckpt_every == 0:
            if args.use_ema:
                optimizerG.swap_parameters_with_ema(
                    store_params_in_ema=True)

            torch.save(netG.state_dict(), os.path.join(
                exp_path, 'netG_{}.pth'.format(epoch)))
            if args.use_ema:
                optimizerG.swap_parameters_with_ema(
                    store_params_in_ema=True)
# Out:
# epoch 0 iteration0, G Loss: 15.543731689453125, D Loss: 1.3861949443817139, alpha: 0.9975273768433652
# epoch 0 iteration100, G Loss: 25.65850830078125, D Loss: 6.20743230683729e-05, alpha: 0.9975273768433652
# OUTTTT
# OUTTTT
# Saving content.
# epoch 1 iteration0, G Loss: 30.098358154296875, D Loss: 0.00025583457318134606, alpha: 0.9973748797433398
# epoch 1 iteration100, G Loss: 149.38856506347656, D Loss: 6.024087895184493e-08, alpha: 0.9973748797433398
# OUTTTT
# OUTTTT
# Saving content.
# epoch 2 iteration0, G Loss: 175.16384887695312, D Loss: 4.880401611328125, alpha: 0.9972130037809577
# epoch 2 iteration100, G Loss: 226.33021545410156, D Loss: 4.410322276271472e-07, alpha: 0.9972130037809577
# OUTTTT
# OUTTTT
# Saving content.
# epoch 3 iteration0, G Loss: 324.65228271484375, D Loss: 2.2813138999208022e-42, alpha: 0.9970411754780928
# epoch 3 iteration100, G Loss: 214.61581420898438, D Loss: 1.8484139218344353e-05, alpha: 0.9970411754780928
# OUTTTT
# OUTTTT
# Saving content.
# epoch 4 iteration0, G Loss: 98.96273040771484, D Loss: 3.207713598385453e-05, alpha: 0.9968587867151706
# epoch 4 iteration100, G Loss: 143.05642700195312, D Loss: 1.078609415117171e-07, alpha: 0.9968587867151706
# OUTTTT
# OUTTTT
# Saving content.
# epoch 5 iteration0, G Loss: 187.2538299560547, D Loss: 6.651347212027758e-05, alpha: 0.9966651926925867
# epoch 5 iteration100, G Loss: 441.65460205078125, D Loss: 0.00019398672156967223, alpha: 0.9966651926925867
# OUTTTT
# OUTTTT
# Saving content.
# epoch 6 iteration0, G Loss: 580.397216796875, D Loss: 8.386650774246735e-30, alpha: 0.9964597097790535
# epoch 6 iteration100, G Loss: 845.724365234375, D Loss: 3.907909393310547, alpha: 0.9964597097790535
# OUTTTT
# OUTTTT
# Saving content.
# epoch 7 iteration0, G Loss: 199.5742950439453, D Loss: 2.934307872237696e-07, alpha: 0.9962416132414992
# epoch 7 iteration100, G Loss: 746.6197509765625, D Loss: 5.03158759102007e-09, alpha: 0.9962416132414992
# OUTTTT
# OUTTTT
# Saving content.
# epoch 8 iteration0, G Loss: 201.89157104492188, D Loss: 3.974314367188869e-13, alpha: 0.9960101348510059
# epoch 8 iteration100, G Loss: 161.65272521972656, D Loss: 4.91493551635358e-07, alpha: 0.9960101348510059
# OUTTTT
# OUTTTT
# Saving content.
# epoch 9 iteration0, G Loss: 774.7179565429688, D Loss: 2.0171695239145097e-16, alpha: 0.9957644603591566
# epoch 9 iteration100, G Loss: 535.4533081054688, D Loss: 8.37945299281273e-06, alpha: 0.9957644603591566
# OUTTTT
# OUTTTT
# Saving content.
# epoch 10 iteration0, G Loss: 525.6583862304688, D Loss: 1.3200518456102373e-10, alpha: 0.9955037268390589
# epoch 10 iteration100, G Loss: 113.73098754882812, D Loss: 6.148445663711755e-07, alpha: 0.9955037268390589
# OUTTTT
# OUTTTT
# Saving content.
# epoch 11 iteration0, G Loss: 64.87452697753906, D Loss: 1.7278399582210113e-06, alpha: 0.9952270198852368
# epoch 11 iteration100, G Loss: 69.34117126464844, D Loss: 5.925337609369308e-05, alpha: 0.9952270198852368
# OUTTTT
# OUTTTT
# Saving content.
# epoch 12 iteration0, G Loss: 467.7275390625, D Loss: 1.5712828371761134e-08, alpha: 0.9949333706665338
# epoch 12 iteration100, G Loss: 610.7454223632812, D Loss: 0.00014585080498363823, alpha: 0.9949333706665338
# OUTTTT
# OUTTTT
# Saving content.
# epoch 13 iteration0, G Loss: 294.9713439941406, D Loss: 1.4679320939578893e-24, alpha: 0.9946217528261514
# epoch 13 iteration100, G Loss: 58.364524841308594, D Loss: 6.308081083261641e-06, alpha: 0.9946217528261514
# OUTTTT
# OUTTTT
# Saving content.
# epoch 14 iteration0, G Loss: 781.7879638671875, D Loss: 1.6936331623165074e-13, alpha: 0.9942910792229767
# epoch 14 iteration100, G Loss: 735.3405151367188, D Loss: 1.5023514376988345e-10, alpha: 0.9942910792229767
# OUTTTT
# OUTTTT
# Saving content.
# epoch 15 iteration0, G Loss: 510.80780029296875, D Loss: 1.197678448510224e-17, alpha: 0.9939401985084159
# epoch 15 iteration100, G Loss: 250.9739227294922, D Loss: 3.598711657559761e-07, alpha: 0.9939401985084159
# OUTTTT
# OUTTTT
# Saving content.
# epoch 16 iteration0, G Loss: 252.01878356933594, D Loss: 2.929967877207673e-07, alpha: 0.9935678915330813
# epoch 16 iteration100, G Loss: 746.7745361328125, D Loss: 1.9011885115105542e-06, alpha: 0.9935678915330813
# OUTTTT
# OUTTTT
# Saving content.
# epoch 17 iteration0, G Loss: 690.4586791992188, D Loss: 4.268986548048565e-22, alpha: 0.9931728675778618
# epoch 17 iteration100, G Loss: 309.73504638671875, D Loss: 1.016082936235032e-21, alpha: 0.9931728675778618
# OUTTTT
# OUTTTT
# Saving content.
# epoch 18 iteration0, G Loss: 398.1079406738281, D Loss: 1.383960515073901e-16, alpha: 0.9927537604041685
# epoch 18 iteration100, G Loss: 179.97450256347656, D Loss: 3.1542252949941514e-17, alpha: 0.9927537604041685
# OUTTTT
# OUTTTT
# Saving content.
# epoch 19 iteration0, G Loss: 460.94195556640625, D Loss: 1.2616893859428185e-18, alpha: 0.9923091241184917
# epoch 19 iteration100, G Loss: 43.75575256347656, D Loss: 1.2368752322799992e-05, alpha: 0.9923091241184917
# OUTTTT
# OUTTTT
# Saving content.
# epoch 20 iteration0, G Loss: 56.460426330566406, D Loss: 7.538301929344016e-07, alpha: 0.9918374288468401
# epoch 20 iteration100, G Loss: 225.53683471679688, D Loss: 2.2911004690651104e-11, alpha: 0.9918374288468401
# OUTTTT
# OUTTTT
# Saving content.
# epoch 21 iteration0, G Loss: 410.04620361328125, D Loss: 7.098528709281737e-11, alpha: 0.9913370562151869
# epoch 21 iteration100, G Loss: 415.6689758300781, D Loss: 1.873411201813724e-05, alpha: 0.9913370562151869
# OUTTTT
# OUTTTT
# Saving content.
# epoch 22 iteration0, G Loss: 530.5758666992188, D Loss: 9.329655357675607e-19, alpha: 0.9908062946327119
# epoch 22 iteration100, G Loss: 316.6255798339844, D Loss: 9.537194367581492e-10, alpha: 0.9908062946327119
# OUTTTT
# OUTTTT
# Saving content.
# epoch 23 iteration0, G Loss: 230.62416076660156, D Loss: 1.473571865062695e-05, alpha: 0.9902433343754486
# epoch 23 iteration100, G Loss: 133.1321258544922, D Loss: 1.570729824105596e-16, alpha: 0.9902433343754486
# OUTTTT
# OUTTTT
# Saving content.
# epoch 24 iteration0, G Loss: 226.9415283203125, D Loss: 9.07755151056185e-16, alpha: 0.9896462624689083
# epoch 24 iteration100, G Loss: 44.48841094970703, D Loss: 2.3159855118137784e-06, alpha: 0.9896462624689083
# OUTTTT
# OUTTTT
# Saving content.
# epoch 25 iteration0, G Loss: 325.94427490234375, D Loss: 1.1950374500732663e-13, alpha: 0.9890130573694068
# epoch 25 iteration100, G Loss: 168.97592163085938, D Loss: 0.0005123521550558507, alpha: 0.9890130573694068
# OUTTTT
# OUTTTT
# Saving content.
# epoch 26 iteration0, G Loss: 314.1390075683594, D Loss: 1.8798620646243158e-11, alpha: 0.9883415834451669
# epoch 26 iteration100, G Loss: 432.8627014160156, D Loss: 1.35633951986458e-11, alpha: 0.9883415834451669
# OUTTTT
# OUTTTT
# Saving content.
# epoch 27 iteration0, G Loss: 432.28851318359375, D Loss: 1.6939545890853755e-16, alpha: 0.9876295852598376
# epoch 27 iteration100, G Loss: 285.69073486328125, D Loss: 3.633623443827424e-17, alpha: 0.9876295852598376
# OUTTTT
# OUTTTT
# Saving content.
# epoch 28 iteration0, G Loss: 185.3842315673828, D Loss: 9.021755862139433e-17, alpha: 0.9868746816628972
# epoch 28 iteration100, G Loss: 528.1341552734375, D Loss: 4.27862705939909e-22, alpha: 0.9868746816628972
# OUTTTT
# OUTTTT
# Saving content.
# epoch 29 iteration0, G Loss: 597.0572509765625, D Loss: 7.165268422144615e-18, alpha: 0.9860743596934997
# epoch 29 iteration100, G Loss: 202.20761108398438, D Loss: 8.947982871147786e-13, alpha: 0.9860743596934997
# OUTTTT
# OUTTTT
# Saving content.
# epoch 30 iteration0, G Loss: 145.0150909423828, D Loss: 1.2643066327200359e-07, alpha: 0.9852259683067269
# epoch 30 iteration100, G Loss: 270.8794860839844, D Loss: 4.141923000133829e-07, alpha: 0.9852259683067269
# OUTTTT
# OUTTTT
# Saving content.
# epoch 31 iteration0, G Loss: 646.6137084960938, D Loss: 7.679115584499998e-43, alpha: 0.9843267119339515
# epoch 31 iteration100, G Loss: 1458.962890625, D Loss: 8.195261416584034e-19, alpha: 0.9843267119339515
# OUTTTT
# OUTTTT
# Saving content.
# epoch 32 iteration0, G Loss: 1118.3660888671875, D Loss: 9.048242869179783e-34, alpha: 0.9833736438921183
# epoch 32 iteration100, G Loss: 344.2723693847656, D Loss: 8.991980172501607e-18, alpha: 0.9833736438921183
# OUTTTT
# OUTTTT
# Saving content.
# epoch 33 iteration0, G Loss: 256.49853515625, D Loss: 2.532830478685355e-08, alpha: 0.9823636596602773
# epoch 33 iteration100, G Loss: 103.8037109375, D Loss: 2.1410401132015977e-06, alpha: 0.9823636596602773
# OUTTTT
# OUTTTT
# Saving content.
# epoch 34 iteration0, G Loss: 268.9080505371094, D Loss: 6.089234366796543e-23, alpha: 0.9812934900456454
# epoch 34 iteration100, G Loss: 567.4182739257812, D Loss: 6.035213510722929e-16, alpha: 0.9812934900456454
# OUTTTT
# OUTTTT
# Saving content.
# epoch 35 iteration0, G Loss: 276.7471618652344, D Loss: 1.2870495132540918e-21, alpha: 0.9801596942659225
# epoch 35 iteration100, G Loss: 283.824462890625, D Loss: 2.911338795892328e-16, alpha: 0.9801596942659225
# OUTTTT
# OUTTTT
# Saving content.
# epoch 36 iteration0, G Loss: 277.7831726074219, D Loss: 6.254097933977576e-12, alpha: 0.9789586529795318
# epoch 36 iteration100, G Loss: 959.2385864257812, D Loss: 4.906646773866678e-21, alpha: 0.9789586529795318
# OUTTTT
# OUTTTT
# Saving content.
# epoch 37 iteration0, G Loss: 800.4051513671875, D Loss: 9.859092097030953e-05, alpha: 0.9776865613009678
# epoch 37 iteration100, G Loss: 258.9088134765625, D Loss: 1.023196860572284e-09, alpha: 0.9776865613009678
# OUTTTT
# OUTTTT
# Saving content.
# epoch 38 iteration0, G Loss: 130.94927978515625, D Loss: 1.8886200905399164e-06, alpha: 0.9763394218445388
# epoch 38 iteration100, G Loss: 202.08412170410156, D Loss: 1.9153953918679125e-15, alpha: 0.9763394218445388
# OUTTTT
# OUTTTT
# Saving content.
# epoch 39 iteration0, G Loss: 326.03533935546875, D Loss: 1.6667360861262574e-24, alpha: 0.9749130378465202
# epoch 39 iteration100, G Loss: 77.44610595703125, D Loss: 1.0310226283838375e-10, alpha: 0.9749130378465202
# OUTTTT
# OUTTTT
# Saving content.
# epoch 40 iteration0, G Loss: 455.34393310546875, D Loss: 1.3881344778152489e-21, alpha: 0.9734030064231342
# epoch 40 iteration100, G Loss: 119.4955062866211, D Loss: 2.0125803920505145e-17, alpha: 0.9734030064231342
# OUTTTT
# OUTTTT
# Saving content.
# epoch 41 iteration0, G Loss: 871.7151489257812, D Loss: 0.4960962235927582, alpha: 0.9718047120298574
# epoch 41 iteration100, G Loss: 80.6197280883789, D Loss: 3.81321189901751e-11, alpha: 0.9718047120298574
# OUTTTT
# OUTTTT
# Saving content.
# epoch 42 iteration0, G Loss: 604.6610107421875, D Loss: 5.142213870940775e-24, alpha: 0.9701133201963638
# epoch 42 iteration100, G Loss: 67.84783935546875, D Loss: 7.285606173261863e-14, alpha: 0.9701133201963638
# OUTTTT
# OUTTTT
# Saving content.
# epoch 43 iteration0, G Loss: 73.7576675415039, D Loss: 3.910203324325456e-12, alpha: 0.9683237716209436
# epoch 43 iteration100, G Loss: 174.82638549804688, D Loss: 5.980266593041961e-08, alpha: 0.9683237716209436
# OUTTTT
# OUTTTT
# Saving content.
# epoch 44 iteration0, G Loss: 326.0394592285156, D Loss: 1.7316247991061573e-08, alpha: 0.9664307767185175
# epoch 44 iteration100, G Loss: 82.31295013427734, D Loss: 1.440619978865243e-08, alpha: 0.9664307767185175
# OUTTTT
# OUTTTT
# Saving content.
# epoch 45 iteration0, G Loss: 320.00982666015625, D Loss: 6.948205032164534e-12, alpha: 0.9644288107273639
# epoch 45 iteration100, G Loss: 507.1116638183594, D Loss: 7.192721895518672e-13, alpha: 0.9644288107273639
# OUTTTT
# OUTTTT
# Saving content.
# epoch 46 iteration0, G Loss: 359.69293212890625, D Loss: 1.4513443398478376e-11, alpha: 0.9623121094913941
# epoch 46 iteration100, G Loss: 536.7923583984375, D Loss: 3.3334942477360864e-20, alpha: 0.9623121094913941
# OUTTTT
# OUTTTT
# Saving content.
# epoch 47 iteration0, G Loss: 666.5264892578125, D Loss: 1.7661679011526588e-23, alpha: 0.9600746660471862
# epoch 47 iteration100, G Loss: 110.65451049804688, D Loss: 2.395873366367596e-07, alpha: 0.9600746660471862
# OUTTTT
# OUTTTT
# Saving content.
# epoch 48 iteration0, G Loss: 120.23414611816406, D Loss: 4.982912971129849e-10, alpha: 0.9577102281579662
# epoch 48 iteration100, G Loss: 202.31275939941406, D Loss: 0.00010841956827789545, alpha: 0.9577102281579662
# OUTTTT
# OUTTTT
# Saving content.
# epoch 49 iteration0, G Loss: 1248.8863525390625, D Loss: 2.997166633605957, alpha: 0.9552122969502133
# epoch 49 iteration100, G Loss: 870.9139404296875, D Loss: 2.2981194999091245e-17, alpha: 0.9552122969502133
# OUTTTT
# OUTTTT
# Saving content.
# epoch 50 iteration0, G Loss: 233.4669189453125, D Loss: 2.594363526092769e-12, alpha: 0.9525741268224333
# epoch 50 iteration100, G Loss: 123.79235076904297, D Loss: 5.24660787744081e-25, alpha: 0.9525741268224333
# OUTTTT
# OUTTTT
# Saving content.
# epoch 51 iteration0, G Loss: 131.08843994140625, D Loss: 6.60050127686382e-15, alpha: 0.9497887268097335
# epoch 51 iteration100, G Loss: 872.1500854492188, D Loss: 5.815591234738587e-17, alpha: 0.9497887268097335
# OUTTTT
# OUTTTT
# Saving content.
# epoch 52 iteration0, G Loss: 324.1671142578125, D Loss: 6.521367647283061e-12, alpha: 0.9468488636019363
# epoch 52 iteration100, G Loss: 302.2789611816406, D Loss: 7.492691754565452e-22, alpha: 0.9468488636019363
# OUTTTT
# OUTTTT
# Saving content.
# epoch 53 iteration0, G Loss: 506.501708984375, D Loss: 3.552546734241442e-23, alpha: 0.9437470664268326
# epoch 53 iteration100, G Loss: 111.39132690429688, D Loss: 1.3862135347153526e-05, alpha: 0.9437470664268326
# OUTTTT
# OUTTTT
# Saving content.
# epoch 54 iteration0, G Loss: 111.18121337890625, D Loss: 1.1381901831153092e-19, alpha: 0.9404756340234985
# epoch 54 iteration100, G Loss: 330.0298156738281, D Loss: 3.5929020668845624e-05, alpha: 0.9404756340234985
# OUTTTT
# OUTTTT
# Saving content.
# epoch 55 iteration0, G Loss: 616.00732421875, D Loss: 1.995919214273353e-15, alpha: 0.9370266439430035
# epoch 55 iteration100, G Loss: 261.6819152832031, D Loss: 2.76627037469184e-16, alpha: 0.9370266439430035
# OUTTTT
# OUTTTT
# Saving content.
# epoch 56 iteration0, G Loss: 571.0034790039062, D Loss: 1.1991968719754743e-32, alpha: 0.9333919644249093
# epoch 56 iteration100, G Loss: 281.9883117675781, D Loss: 7.950993162475495e-12, alpha: 0.9333919644249093
# OUTTTT
# OUTTTT
# Saving content.
# epoch 57 iteration0, G Loss: 699.7026977539062, D Loss: 3.548691570997627e-24, alpha: 0.9295632691071829
# epoch 57 iteration100, G Loss: 1007.9307250976562, D Loss: 0.013603253290057182, alpha: 0.9295632691071829
# OUTTTT
# OUTTTT
# Saving content.
# epoch 58 iteration0, G Loss: 488.8216552734375, D Loss: 1.2875030419363222e-26, alpha: 0.9255320548339719
# epoch 58 iteration100, G Loss: 703.6927490234375, D Loss: 3.343723961648474e-30, alpha: 0.9255320548339719
# OUTTTT
# OUTTTT
# Saving content.
# epoch 59 iteration0, G Loss: 820.918701171875, D Loss: 3.692654211781407e-21, alpha: 0.9212896628294648
# epoch 59 iteration100, G Loss: 700.6385498046875, D Loss: 2.732423731721667e-10, alpha: 0.9212896628294648
# OUTTTT
# OUTTTT
# Saving content.
# epoch 60 iteration0, G Loss: 1063.5833740234375, D Loss: 1.3115179369620249e-24, alpha: 0.9168273035060777
# epoch 60 iteration100, G Loss: 762.4960327148438, D Loss: 2.4779130774950664e-22, alpha: 0.9168273035060777
# OUTTTT
# OUTTTT
# Saving content.
# epoch 61 iteration0, G Loss: 431.46771240234375, D Loss: 5.2530119143412435e-11, alpha: 0.9121360851706988
# epoch 61 iteration100, G Loss: 147.1036834716797, D Loss: 5.739668267779052e-06, alpha: 0.9121360851706988
# OUTTTT
# OUTTTT
# Saving content.
# epoch 62 iteration0, G Loss: 201.00990295410156, D Loss: 5.75146077608224e-06, alpha: 0.907207046882843
# epoch 62 iteration100, G Loss: 66.97367095947266, D Loss: 2.8752586249403134e-13, alpha: 0.907207046882843
# OUTTTT
# OUTTTT
# Saving content.
# epoch 63 iteration0, G Loss: 512.10107421875, D Loss: 5.78909334711691e-26, alpha: 0.902031195702446
# epoch 63 iteration100, G Loss: 17.311702728271484, D Loss: 9.059665899258107e-06, alpha: 0.902031195702446
# OUTTTT
# OUTTTT
# Saving content.
# epoch 64 iteration0, G Loss: 44.53075408935547, D Loss: 3.565467704902403e-05, alpha: 0.8965995485417504
# epoch 64 iteration100, G Loss: 43.70795440673828, D Loss: 9.27580456888677e-10, alpha: 0.8965995485417504
# OUTTTT
# OUTTTT
# Saving content.
# epoch 65 iteration0, G Loss: 454.33819580078125, D Loss: 9.698799181688116e-19, alpha: 0.8909031788043871
# epoch 65 iteration100, G Loss: 292.85223388671875, D Loss: 4.0514619247368835e-15, alpha: 0.8909031788043871
# OUTTTT
# OUTTTT
# Saving content.
# epoch 66 iteration0, G Loss: 287.9494934082031, D Loss: 1.1225550620075266e-14, alpha: 0.8849332679544502
# epoch 66 iteration100, G Loss: 60.772525787353516, D Loss: 1.5783922435730346e-07, alpha: 0.8849332679544502
# OUTTTT
# OUTTTT
# Saving content.
# epoch 67 iteration0, G Loss: 74.78688049316406, D Loss: 1.108141759686987e-06, alpha: 0.8786811621082632
# epoch 67 iteration100, G Loss: 129.76206970214844, D Loss: 2.2016641842981244e-09, alpha: 0.8786811621082632
# OUTTTT
# OUTTTT
# Saving content.
# epoch 68 iteration0, G Loss: 131.7542724609375, D Loss: 6.085754478135641e-08, alpha: 0.8721384336809187
# epoch 68 iteration100, G Loss: 86.72891235351562, D Loss: 2.2138493169524272e-17, alpha: 0.8721384336809187
# OUTTTT
# OUTTTT
# Saving content.
# epoch 69 iteration0, G Loss: 91.88523864746094, D Loss: 2.0432920729473916e-15, alpha: 0.865296948047972
# epoch 69 iteration100, G Loss: 1209.6868896484375, D Loss: 7.658133753774257e-20, alpha: 0.865296948047972
# OUTTTT
# OUTTTT
# Saving content.
# epoch 70 iteration0, G Loss: 904.8169555664062, D Loss: 1.226654826087363e-27, alpha: 0.8581489350995122
# epoch 70 iteration100, G Loss: 241.95083618164062, D Loss: 1.3853733438207172e-10, alpha: 0.8581489350995122
# OUTTTT
# OUTTTT
# Saving content.
# epoch 71 iteration0, G Loss: 181.0697021484375, D Loss: 2.8424203962762462e-11, alpha: 0.8506870654691563
# epoch 71 iteration100, G Loss: 251.6524200439453, D Loss: 3.7854940728720976e-06, alpha: 0.8506870654691563
# OUTTTT
# OUTTTT
# Saving content.
# epoch 72 iteration0, G Loss: 237.85797119140625, D Loss: 2.4599686708221685e-14, alpha: 0.8429045311145472
# epoch 72 iteration100, G Loss: 285.61346435546875, D Loss: 6.247303022122175e-14, alpha: 0.8429045311145472
# OUTTTT
# OUTTTT
# Saving content.
# epoch 73 iteration0, G Loss: 859.6458740234375, D Loss: 0.0002098624245263636, alpha: 0.8347951298093854
# epoch 73 iteration100, G Loss: 279.130859375, D Loss: 1.4812517878937115e-09, alpha: 0.8347951298093854
# OUTTTT
# OUTTTT
# Saving content.
# epoch 74 iteration0, G Loss: 550.5491333007812, D Loss: 1.0634527744544524e-28, alpha: 0.826353352980995
# epoch 74 iteration100, G Loss: 108.58795166015625, D Loss: 1.33355804697588e-12, alpha: 0.826353352980995
# OUTTTT
# OUTTTT
# Saving content.
# epoch 75 iteration0, G Loss: 70.29889678955078, D Loss: 1.5877007485966786e-14, alpha: 0.8175744761936437
# epoch 75 iteration100, G Loss: 796.6026611328125, D Loss: 2.7359704779517102e-11, alpha: 0.8175744761936437
# OUTTTT
# OUTTTT
# Saving content.
# epoch 76 iteration0, G Loss: 890.5843505859375, D Loss: 4.351799476332019e-11, alpha: 0.8084546514385326
# epoch 76 iteration100, G Loss: 71.57681274414062, D Loss: 2.5750448440220453e-09, alpha: 0.8084546514385326
# OUTTTT
# OUTTTT
# Saving content.
# epoch 77 iteration0, G Loss: 67.64163208007812, D Loss: 1.4104301060413604e-10, alpha: 0.7989910002494707
# epoch 77 iteration100, G Loss: 86.27981567382812, D Loss: 1.2595834965323238e-11, alpha: 0.7989910002494707
# OUTTTT
# OUTTTT
# Saving content.
# epoch 78 iteration0, G Loss: 72.21659851074219, D Loss: 6.35619926470099e-07, alpha: 0.789181706522253
# epoch 78 iteration100, G Loss: 304.5007019042969, D Loss: 1.1675788869069947e-07, alpha: 0.789181706522253
# OUTTTT
# OUTTTT
# Saving content.
# epoch 79 iteration0, G Loss: 142.29791259765625, D Loss: 1.533923541571086e-13, alpha: 0.7790261077798122
# epoch 79 iteration100, G Loss: 95.62444305419922, D Loss: 6.0505584542625e-07, alpha: 0.7790261077798122
# OUTTTT
# OUTTTT
# Saving content.
# epoch 80 iteration0, G Loss: 153.14291381835938, D Loss: 5.626830551247897e-15, alpha: 0.7685247834990176
# epoch 80 iteration100, G Loss: 648.8576049804688, D Loss: 2.742880766959388e-08, alpha: 0.7685247834990176
# OUTTTT
# OUTTTT
# Saving content.
# epoch 81 iteration0, G Loss: 420.03741455078125, D Loss: 3.3503220911363415e-16, alpha: 0.7576796390037049
# epoch 81 iteration100, G Loss: 559.6591186523438, D Loss: 0.7767888307571411, alpha: 0.7576796390037049
# OUTTTT
# OUTTTT
# Saving content.
# epoch 82 iteration0, G Loss: 209.4219207763672, D Loss: 1.0408025906842613e-18, alpha: 0.7464939833376623
# epoch 82 iteration100, G Loss: 308.4779357910156, D Loss: 4.151201663181143e-22, alpha: 0.7464939833376623
# OUTTTT
# OUTTTT
# Saving content.
# epoch 83 iteration0, G Loss: 253.77867126464844, D Loss: 2.0443801150990757e-20, alpha: 0.7349725994665188
# epoch 83 iteration100, G Loss: 181.74400329589844, D Loss: 1.1585959016463798e-17, alpha: 0.7349725994665188
# OUTTTT
# OUTTTT
# Saving content.
# epoch 84 iteration0, G Loss: 195.91172790527344, D Loss: 0.907640814781189, alpha: 0.7231218051243897
# epoch 84 iteration100, G Loss: 506.46478271484375, D Loss: 1.136139188786484e-18, alpha: 0.7231218051243897
# OUTTTT
# OUTTTT
# Saving content.
# epoch 85 iteration0, G Loss: 312.2421569824219, D Loss: 5.356131120223817e-13, alpha: 0.710949502625004
# epoch 85 iteration100, G Loss: 1063.5225830078125, D Loss: 1.2806723681535459e-08, alpha: 0.710949502625004
# OUTTTT
# OUTTTT
# Saving content.
# epoch 86 iteration0, G Loss: 1561.0484619140625, D Loss: 245.27464294433594, alpha: 0.6984652160025386
# epoch 86 iteration100, G Loss: 1146.3701171875, D Loss: 7.447476337886505e-13, alpha: 0.6984652160025386
# OUTTTT
# OUTTTT
# Saving content.
# epoch 87 iteration0, G Loss: 846.4193725585938, D Loss: 6.185233765942404e-17, alpha: 0.6856801139382539
# epoch 87 iteration100, G Loss: 132.27633666992188, D Loss: 0.028120728209614754, alpha: 0.6856801139382539
# OUTTTT
# OUTTTT
# Saving content.
# epoch 88 iteration0, G Loss: 391.62127685546875, D Loss: 9.759268111058243e-17, alpha: 0.6726070170677605
# epoch 88 iteration100, G Loss: 86.24120330810547, D Loss: 7.656838487898887e-13, alpha: 0.6726070170677605
# OUTTTT
# OUTTTT
# Saving content.
# epoch 89 iteration0, G Loss: 160.47640991210938, D Loss: 9.701611958234935e-09, alpha: 0.6592603884513855
# epoch 89 iteration100, G Loss: 418.6972351074219, D Loss: 2.891544694706179e-16, alpha: 0.6592603884513855
# OUTTTT
# OUTTTT
# Saving content.
# epoch 90 iteration0, G Loss: 486.3183288574219, D Loss: 3.793142302956475e-38, alpha: 0.6456563062257956
# epoch 90 iteration100, G Loss: 290.8723449707031, D Loss: 2.1849668883078266e-06, alpha: 0.6456563062257956
# OUTTTT
# OUTTTT
# Saving content.
# epoch 91 iteration0, G Loss: 252.44253540039062, D Loss: 8.331701756465748e-13, alpha: 0.6318124177361018
# epoch 91 iteration100, G Loss: 161.7275390625, D Loss: 2.250835490068236e-22, alpha: 0.6318124177361018
# OUTTTT
# OUTTTT
# Saving content.
# epoch 92 iteration0, G Loss: 226.67430114746094, D Loss: 8.668645662401886e-12, alpha: 0.6177478747692491
# epoch 92 iteration100, G Loss: 260.49920654296875, D Loss: 2.4412612705556995e-14, alpha: 0.6177478747692491
# OUTTTT
# OUTTTT
# Saving content.
# epoch 93 iteration0, G Loss: 73.64356231689453, D Loss: 11.237573623657227, alpha: 0.6034832498647262
# epoch 93 iteration100, G Loss: 276.74432373046875, D Loss: 1.7875041891102228e-08, alpha: 0.6034832498647262
# OUTTTT
# OUTTTT
# Saving content.
# epoch 94 iteration0, G Loss: 67.23067474365234, D Loss: 1.9146521119863674e-13, alpha: 0.5890404340586652
# epoch 94 iteration100, G Loss: 185.01303100585938, D Loss: 3.077926885453053e-05, alpha: 0.5890404340586652
# OUTTTT
# OUTTTT
# Saving content.
# epoch 95 iteration0, G Loss: 339.021484375, D Loss: 6.1854804459433e-23, alpha: 0.5744425168116589
# epoch 95 iteration100, G Loss: 212.0043487548828, D Loss: 1.4569512131856754e-05, alpha: 0.5744425168116589
# OUTTTT
# OUTTTT
# Saving content.
# epoch 96 iteration0, G Loss: 195.15182495117188, D Loss: 5.72375697185934e-13, alpha: 0.559713649267193
# epoch 96 iteration100, G Loss: 46.15163040161133, D Loss: 2.0222005048253777e-07, alpha: 0.559713649267193
# OUTTTT
# OUTTTT
# Saving content.
# epoch 97 iteration0, G Loss: 44.4481201171875, D Loss: 2.5001821768455557e-07, alpha: 0.5448788923735802
# epoch 97 iteration100, G Loss: 513.3728637695312, D Loss: 1.1240045217275271e-13, alpha: 0.5448788923735802
# OUTTTT
# OUTTTT
# Saving content.
# epoch 98 iteration0, G Loss: 816.0806274414062, D Loss: 1.061781406402588, alpha: 0.5299640517645718
# epoch 98 iteration100, G Loss: 977.5062255859375, D Loss: 1.2422298141245847e-06, alpha: 0.5299640517645718
# OUTTTT
# OUTTTT
# Saving content.
# epoch 99 iteration0, G Loss: 1226.0076904296875, D Loss: 1.3002221989113176e-19, alpha: 0.5149955016194101
# epoch 99 iteration100, G Loss: 1336.86083984375, D Loss: 1.4465064541953272e-30, alpha: 0.5149955016194101
# OUTTTT
# OUTTTT
# Saving content.
# epoch 100 iteration0, G Loss: 1171.50439453125, D Loss: 3.115707464334497e-16, alpha: 0.5
# epoch 100 iteration100, G Loss: 578.6513671875, D Loss: 4.4133915312608e-35, alpha: 0.5
# OUTTTT
# OUTTTT
# Saving content.
# epoch 101 iteration0, G Loss: 2516.63232421875, D Loss: 1.2569647224993609e-42, alpha: 0.48500449838059
# epoch 101 iteration100, G Loss: 3790.806640625, D Loss: 2.12243058510523e-34, alpha: 0.48500449838059
# OUTTTT
# OUTTTT
# Saving content.
# epoch 102 iteration0, G Loss: 757.010498046875, D Loss: 1.2034855103806437e-20, alpha: 0.47003594823542827
# epoch 102 iteration100, G Loss: 546.5435791015625, D Loss: 2.1681486298394563e-21, alpha: 0.47003594823542827
# OUTTTT
# OUTTTT
# Saving content.
# epoch 103 iteration0, G Loss: 386.8869323730469, D Loss: 1.7231462567587896e-12, alpha: 0.45512110762642
# epoch 103 iteration100, G Loss: 1442.7183837890625, D Loss: 8.794628127808094e-26, alpha: 0.45512110762642
# OUTTTT
# OUTTTT
# Saving content.
# epoch 104 iteration0, G Loss: 127.3531494140625, D Loss: 1.110041125684802e-06, alpha: 0.4402863507328071
# epoch 104 iteration100, G Loss: 578.4769287109375, D Loss: 5.055661445041437e-10, alpha: 0.4402863507328071
# OUTTTT
# OUTTTT
# Saving content.
# epoch 105 iteration0, G Loss: 195.29681396484375, D Loss: 1.2623127379988643e-23, alpha: 0.4255574831883411
# epoch 105 iteration100, G Loss: 607.3864135742188, D Loss: 9.67641966553856e-09, alpha: 0.4255574831883411
# OUTTTT
# OUTTTT
# Saving content.
# epoch 106 iteration0, G Loss: 994.9217529296875, D Loss: 4.9797722865144935e-21, alpha: 0.4109595659413351
# epoch 106 iteration100, G Loss: 1018.873291015625, D Loss: 1.8736654965323396e-05, alpha: 0.4109595659413351
# OUTTTT
# OUTTTT
# Saving content.
# epoch 107 iteration0, G Loss: 1103.373779296875, D Loss: 1.337867703177665e-14, alpha: 0.39651675013527377
# epoch 107 iteration100, G Loss: 415.2006530761719, D Loss: 0.01563272438943386, alpha: 0.39651675013527377
# OUTTTT
# OUTTTT
# Saving content.
# epoch 108 iteration0, G Loss: 305.4717712402344, D Loss: 3.8836197712582843e-13, alpha: 0.38225212523075114
# epoch 108 iteration100, G Loss: 594.2310791015625, D Loss: 5.399293012686712e-09, alpha: 0.38225212523075114
# OUTTTT
# OUTTTT
# Saving content.
# epoch 109 iteration0, G Loss: 648.8077392578125, D Loss: 1.7018508221255822e-17, alpha: 0.36818758226389836
# epoch 109 iteration100, G Loss: 219.7056884765625, D Loss: 3.4127375849631696e-21, alpha: 0.36818758226389836
# OUTTTT
# OUTTTT
# Saving content.
# epoch 110 iteration0, G Loss: 191.24514770507812, D Loss: 2.7782749491368016e-16, alpha: 0.3543436937742046
# epoch 110 iteration100, G Loss: 86.41398620605469, D Loss: 6.37443182548332e-14, alpha: 0.3543436937742046
# OUTTTT
# OUTTTT
# Saving content.
# epoch 111 iteration0, G Loss: 374.5120544433594, D Loss: 1.1369894775166292e-15, alpha: 0.34073961154861454
# epoch 111 iteration100, G Loss: 168.52195739746094, D Loss: 1.4918871329714256e-18, alpha: 0.34073961154861454
# OUTTTT
# OUTTTT
# Saving content.
# epoch 112 iteration0, G Loss: 219.21392822265625, D Loss: 3.1365868125021734e-08, alpha: 0.3273929829322396
# epoch 112 iteration100, G Loss: 3.416264533996582, D Loss: 0.017899813130497932, alpha: 0.3273929829322396
# OUTTTT
# OUTTTT
# Saving content.
# epoch 113 iteration0, G Loss: 507.6485900878906, D Loss: 3.564338824091351e-09, alpha: 0.3143198860617463
# epoch 113 iteration100, G Loss: 165.03077697753906, D Loss: 1.713440056505533e-08, alpha: 0.3143198860617463
# OUTTTT
# OUTTTT
# Saving content.
# epoch 114 iteration0, G Loss: 339.0118713378906, D Loss: 2.752338135181276e-09, alpha: 0.30153478399746125
# epoch 114 iteration100, G Loss: 734.2634887695312, D Loss: 1.7267749730098814e-10, alpha: 0.30153478399746125
# OUTTTT
# OUTTTT
# Saving content.
# epoch 115 iteration0, G Loss: 468.47332763671875, D Loss: 7.150895662693139e-16, alpha: 0.2890504973749961
# epoch 115 iteration100, G Loss: 249.26242065429688, D Loss: 1.763841339652572e-07, alpha: 0.2890504973749961
# OUTTTT
# OUTTTT
# Saving content.
# epoch 116 iteration0, G Loss: 238.6517333984375, D Loss: 1.3314415125975643e-09, alpha: 0.27687819487561016
# epoch 116 iteration100, G Loss: 146.1331024169922, D Loss: 2.6122745968042062e-15, alpha: 0.27687819487561016
# OUTTTT
# OUTTTT
# Saving content.
# epoch 117 iteration0, G Loss: 530.181884765625, D Loss: 8.034108538682804e-19, alpha: 0.26502740053348117
# epoch 117 iteration100, G Loss: 167.4801788330078, D Loss: 6.412997518508937e-20, alpha: 0.26502740053348117
# OUTTTT
# OUTTTT
# Saving content.
# epoch 118 iteration0, G Loss: 1074.458984375, D Loss: 2.7508117533239194e-35, alpha: 0.25350601666233785
# epoch 118 iteration100, G Loss: 101.8028335571289, D Loss: 5.882644149579619e-09, alpha: 0.25350601666233785
# OUTTTT
# OUTTTT
# Saving content.
# epoch 119 iteration0, G Loss: 92.53984832763672, D Loss: 1.0998456190236539e-07, alpha: 0.24232036099629517
# epoch 119 iteration100, G Loss: 451.81304931640625, D Loss: 4.949149559819359e-15, alpha: 0.24232036099629517
# OUTTTT
# OUTTTT
# Saving content.
# epoch 120 iteration0, G Loss: 452.30877685546875, D Loss: 2.4597348897287263e-12, alpha: 0.23147521650098246
# epoch 120 iteration100, G Loss: 729.802490234375, D Loss: 1.9227638858865248e-07, alpha: 0.23147521650098246
# OUTTTT
# OUTTTT
# Saving content.
# epoch 121 iteration0, G Loss: 462.5745544433594, D Loss: 8.946723824010405e-07, alpha: 0.22097389222018782
# epoch 121 iteration100, G Loss: 389.8415222167969, D Loss: 4.600808622967634e-09, alpha: 0.22097389222018782
# OUTTTT
# OUTTTT
# Saving content.
# epoch 122 iteration0, G Loss: 352.85797119140625, D Loss: 2.178285831178073e-05, alpha: 0.21081829347774717
# epoch 122 iteration100, G Loss: 324.31854248046875, D Loss: 3.0873973516643005e-11, alpha: 0.21081829347774717
# OUTTTT
# OUTTTT
# Saving content.
# epoch 123 iteration0, G Loss: 325.1595153808594, D Loss: 5.5671155185788024e-11, alpha: 0.20100899975052933
# epoch 123 iteration100, G Loss: 294.2718811035156, D Loss: 1.1323339599300652e-08, alpha: 0.20100899975052933
# OUTTTT
# OUTTTT
# Saving content.
# epoch 124 iteration0, G Loss: 663.6746826171875, D Loss: 6.140427178870529e-16, alpha: 0.19154534856146754
# epoch 124 iteration100, G Loss: 150.08651733398438, D Loss: 5.4935115484378017e-11, alpha: 0.19154534856146754
# OUTTTT
# OUTTTT
# Saving content.
# epoch 125 iteration0, G Loss: 50.6455078125, D Loss: 1.1917887832169072e-06, alpha: 0.18242552380635635
# epoch 125 iteration100, G Loss: 84.3721923828125, D Loss: 0.0014644229086115956, alpha: 0.18242552380635635
# OUTTTT
# OUTTTT
# Saving content.
# epoch 126 iteration0, G Loss: 73.58592224121094, D Loss: 2.6274628631660357e-13, alpha: 0.173646647019005
# epoch 126 iteration100, G Loss: 68.971923828125, D Loss: 3.125637419998384e-07, alpha: 0.173646647019005
# OUTTTT
# OUTTTT
# Saving content.
# epoch 127 iteration0, G Loss: 430.5960388183594, D Loss: 3.136558124339217e-09, alpha: 0.16520487019061458
# epoch 127 iteration100, G Loss: 528.83544921875, D Loss: 1.1019420931290824e-09, alpha: 0.16520487019061458
# OUTTTT
# OUTTTT
# Saving content.
# epoch 128 iteration0, G Loss: 95.17389678955078, D Loss: 8.02207900613081e-20, alpha: 0.15709546888545278
# epoch 128 iteration100, G Loss: 69.25909423828125, D Loss: 9.04645673927007e-08, alpha: 0.15709546888545278
# OUTTTT
# OUTTTT
# Saving content.
# epoch 129 iteration0, G Loss: 407.36273193359375, D Loss: 1.9630880054795396e-15, alpha: 0.14931293453084382
# epoch 129 iteration100, G Loss: 511.2208557128906, D Loss: 1.9504469220277265e-11, alpha: 0.14931293453084382
# OUTTTT
# OUTTTT
# Saving content.
# epoch 130 iteration0, G Loss: 236.00881958007812, D Loss: 3.825487874564715e-05, alpha: 0.1418510649004877
# epoch 130 iteration100, G Loss: 232.99400329589844, D Loss: 1.6358619348011416e-07, alpha: 0.1418510649004877
# OUTTTT
# OUTTTT
# Saving content.
# epoch 131 iteration0, G Loss: 189.58151245117188, D Loss: 6.51199443382211e-05, alpha: 0.13470305195202814
# epoch 131 iteration100, G Loss: 168.64181518554688, D Loss: 9.714613113942505e-09, alpha: 0.13470305195202814
# OUTTTT
# OUTTTT
# Saving content.
# epoch 132 iteration0, G Loss: 178.87387084960938, D Loss: 1.1789981968143848e-12, alpha: 0.1278615663190813
# epoch 132 iteration100, G Loss: 198.6068878173828, D Loss: 2.6099012951892944e-14, alpha: 0.1278615663190813
# OUTTTT
# OUTTTT
# Saving content.
# epoch 133 iteration0, G Loss: 1.403484582901001, D Loss: 2.8781347083395303e-08, alpha: 0.12131883789173692
# epoch 133 iteration100, G Loss: 435.43536376953125, D Loss: 9.37416643864708e-07, alpha: 0.12131883789173692
# OUTTTT
# OUTTTT
# Saving content.
# epoch 134 iteration0, G Loss: 490.9212341308594, D Loss: 4.7812558356952195e-09, alpha: 0.11506673204554996
# epoch 134 iteration100, G Loss: 175.48605346679688, D Loss: 2.217554566641411e-07, alpha: 0.11506673204554996
# OUTTTT
# OUTTTT
# Saving content.
# epoch 135 iteration0, G Loss: 160.80433654785156, D Loss: 2.912531726906309e-07, alpha: 0.10909682119561293
# epoch 135 iteration100, G Loss: 617.7322998046875, D Loss: 3.0107688075986516e-07, alpha: 0.10909682119561293
# OUTTTT
# OUTTTT
# Saving content.
# epoch 136 iteration0, G Loss: 544.6360473632812, D Loss: 1.7050571396159603e-17, alpha: 0.10340045145824961
# epoch 136 iteration100, G Loss: 535.0654296875, D Loss: 4.705272257162375e-15, alpha: 0.10340045145824961
# OUTTTT
# OUTTTT
# Saving content.
# epoch 137 iteration0, G Loss: 148.9941864013672, D Loss: 1.923247802335104e-12, alpha: 0.09796880429755406
# epoch 137 iteration100, G Loss: 484.0060729980469, D Loss: 1.8075097450533082e-17, alpha: 0.09796880429755406
# OUTTTT
# OUTTTT
# Saving content.
# epoch 138 iteration0, G Loss: 371.68328857421875, D Loss: 6.610641811732876e-09, alpha: 0.09279295311715707
# epoch 138 iteration100, G Loss: 571.7239379882812, D Loss: 1.2439252752849406e-11, alpha: 0.09279295311715707
# OUTTTT
# OUTTTT
# Saving content.
# epoch 139 iteration0, G Loss: 538.2349853515625, D Loss: 1.2689407901181338e-12, alpha: 0.08786391482930123
# epoch 139 iteration100, G Loss: 388.8193054199219, D Loss: 1.7536344791409944e-18, alpha: 0.08786391482930123
# OUTTTT
# OUTTTT
# Saving content.
# epoch 140 iteration0, G Loss: 450.57489013671875, D Loss: 3.401795988997036e-13, alpha: 0.08317269649392234
# epoch 140 iteration100, G Loss: 432.0973205566406, D Loss: 2.5956401402695527e-14, alpha: 0.08317269649392234
# OUTTTT
# OUTTTT
# Saving content.
# epoch 141 iteration0, G Loss: 660.1484375, D Loss: 3.3913665822001665e-19, alpha: 0.07871033717053533
# epoch 141 iteration100, G Loss: 261.9659118652344, D Loss: 4.960351248674277e-13, alpha: 0.07871033717053533
# OUTTTT
# OUTTTT
# Saving content.
# epoch 142 iteration0, G Loss: 606.5906372070312, D Loss: 1.3720706871235127e-16, alpha: 0.07446794516602806
# epoch 142 iteration100, G Loss: 344.64715576171875, D Loss: 3.418412200442006e-14, alpha: 0.07446794516602806
# OUTTTT
# OUTTTT
# Saving content.
# epoch 143 iteration0, G Loss: 455.8822326660156, D Loss: 2.562780210269011e-08, alpha: 0.07043673089281699
# epoch 143 iteration100, G Loss: 853.357177734375, D Loss: 2.1737117012172716e-17, alpha: 0.07043673089281699
# OUTTTT
# OUTTTT
# Saving content.
# epoch 144 iteration0, G Loss: 738.775146484375, D Loss: 4.902935279993414e-10, alpha: 0.06660803557509065
# epoch 144 iteration100, G Loss: 698.2781372070312, D Loss: 5.592801222142896e-10, alpha: 0.06660803557509065
# OUTTTT
# OUTTTT
# Saving content.
# epoch 145 iteration0, G Loss: 688.4107055664062, D Loss: 6.670174256595366e-23, alpha: 0.0629733560569965
# epoch 145 iteration100, G Loss: 742.5556640625, D Loss: 1.5396825481239773e-10, alpha: 0.0629733560569965
# OUTTTT
# OUTTTT
# Saving content.
# epoch 146 iteration0, G Loss: 882.1069946289062, D Loss: 1.1111213702114837e-27, alpha: 0.05952436597650157
# epoch 146 iteration100, G Loss: 505.03143310546875, D Loss: 3.903073227835181e-22, alpha: 0.05952436597650157
# OUTTTT
# OUTTTT
# Saving content.
# epoch 147 iteration0, G Loss: 543.517333984375, D Loss: 4.714976078364357e-16, alpha: 0.056252933573167296
# epoch 147 iteration100, G Loss: 108.11895751953125, D Loss: 3.278385592511701e-12, alpha: 0.056252933573167296
# OUTTTT
# OUTTTT
# Saving content.
# epoch 148 iteration0, G Loss: 164.4216766357422, D Loss: 1.0581084619598613e-10, alpha: 0.05315113639806379
# epoch 148 iteration100, G Loss: 127.38471984863281, D Loss: 1.6883552463546877e-19, alpha: 0.05315113639806379
# OUTTTT
# OUTTTT
# Saving content.
# epoch 149 iteration0, G Loss: 615.7630004882812, D Loss: 1.1433717913648516e-16, alpha: 0.050211273190266636
# epoch 149 iteration100, G Loss: 432.5487976074219, D Loss: 2.2814001944959576e-17, alpha: 0.050211273190266636
# OUTTTT
# OUTTTT
# Saving content.
# epoch 150 iteration0, G Loss: 332.6269226074219, D Loss: 9.498346890845946e-16, alpha: 0.047425873177566635
# epoch 150 iteration100, G Loss: 144.90048217773438, D Loss: 5.350150544813914e-08, alpha: 0.047425873177566635
# OUTTTT
# OUTTTT
# Saving content.
# epoch 151 iteration0, G Loss: 144.85983276367188, D Loss: 3.1971549674381095e-07, alpha: 0.04478770304978663
# epoch 151 iteration100, G Loss: 441.78961181640625, D Loss: 7.615252317627608e-10, alpha: 0.04478770304978663
# OUTTTT
# OUTTTT
# Saving content.
# epoch 152 iteration0, G Loss: 718.250244140625, D Loss: 8.336680908356076e-17, alpha: 0.04228977184203375
# epoch 152 iteration100, G Loss: 511.4516906738281, D Loss: 1.4179073496919936e-12, alpha: 0.04228977184203375
# OUTTTT
# OUTTTT
# Saving content.
# epoch 153 iteration0, G Loss: 165.24545288085938, D Loss: 7.615789413452148, alpha: 0.039925333952813946
# epoch 153 iteration100, G Loss: 240.06446838378906, D Loss: 1.2194696807910077e-07, alpha: 0.039925333952813946
# OUTTTT
# OUTTTT
# Saving content.
# epoch 154 iteration0, G Loss: 231.63157653808594, D Loss: 5.410054028033645e-17, alpha: 0.03768789050860588
# epoch 154 iteration100, G Loss: 613.1552734375, D Loss: 3.5330675017541946e-12, alpha: 0.03768789050860588
# OUTTTT
# OUTTTT
# Saving content.
# epoch 155 iteration0, G Loss: 448.5606994628906, D Loss: 5.523928343369125e-17, alpha: 0.03557118927263614
# epoch 155 iteration100, G Loss: 314.6284484863281, D Loss: 3.146830737069291e-14, alpha: 0.03557118927263614
# OUTTTT
# OUTTTT
# Saving content.
# epoch 156 iteration0, G Loss: 313.132568359375, D Loss: 5.5940190359701075e-15, alpha: 0.033569223281482485
# epoch 156 iteration100, G Loss: 161.4693145751953, D Loss: 1.442048357229415e-20, alpha: 0.033569223281482485
# OUTTTT
# OUTTTT
# Saving content.
# epoch 157 iteration0, G Loss: 481.2812194824219, D Loss: 1.9025215498608312e-14, alpha: 0.03167622837905637
# epoch 157 iteration100, G Loss: 293.1624755859375, D Loss: 3.247293291536624e-15, alpha: 0.03167622837905637
# OUTTTT
# OUTTTT
# Saving content.
# epoch 158 iteration0, G Loss: 189.24876403808594, D Loss: 2.0592784538026583e-21, alpha: 0.02988667980363613
# epoch 158 iteration100, G Loss: 156.117431640625, D Loss: 2.5345028267960423e-14, alpha: 0.02988667980363613
# OUTTTT
# OUTTTT
# Saving content.
# epoch 159 iteration0, G Loss: 571.53271484375, D Loss: 5.5508160146162835e-17, alpha: 0.02819528797014259
# epoch 159 iteration100, G Loss: 625.7926025390625, D Loss: 4.4449981473349e-09, alpha: 0.02819528797014259
# OUTTTT
# OUTTTT
# Saving content.
# epoch 160 iteration0, G Loss: 434.6542663574219, D Loss: 3.081005096232728e-14, alpha: 0.026596993576865957
# epoch 160 iteration100, G Loss: 218.90826416015625, D Loss: 3.220795736037138e-19, alpha: 0.026596993576865957
# OUTTTT
# OUTTTT
# Saving content.
# epoch 161 iteration0, G Loss: 226.13973999023438, D Loss: 1.4838544624688702e-23, alpha: 0.02508696215347972
# epoch 161 iteration100, G Loss: 636.71337890625, D Loss: 4.008959061025994e-22, alpha: 0.02508696215347972
# OUTTTT
# OUTTTT
# Saving content.
# epoch 162 iteration0, G Loss: 632.1229248046875, D Loss: 4.622176489725183e-34, alpha: 0.023660578155461187
# epoch 162 iteration100, G Loss: 159.12611389160156, D Loss: 2.9701196363474125e-11, alpha: 0.023660578155461187
# OUTTTT
# OUTTTT
# Saving content.
# epoch 163 iteration0, G Loss: 132.9609375, D Loss: 1.6825002502329767e-10, alpha: 0.02231343869903235
# epoch 163 iteration100, G Loss: 217.3625030517578, D Loss: 1.3372323254489875e-22, alpha: 0.02231343869903235
# OUTTTT
# OUTTTT
# Saving content.
# epoch 164 iteration0, G Loss: 242.56187438964844, D Loss: 1.965110854160842e-18, alpha: 0.021041347020468337
# epoch 164 iteration100, G Loss: 86.91195678710938, D Loss: 8.89837319846265e-05, alpha: 0.021041347020468337
# OUTTTT
# OUTTTT
# Saving content.
# epoch 165 iteration0, G Loss: 92.33345794677734, D Loss: 2.073405891422908e-10, alpha: 0.019840305734077468
# epoch 165 iteration100, G Loss: 104.05948638916016, D Loss: 2.1583984562312253e-05, alpha: 0.019840305734077468
# OUTTTT
# OUTTTT
# Saving content.
# epoch 166 iteration0, G Loss: 317.156494140625, D Loss: 2.8489404257925344e-07, alpha: 0.018706509954354522
# epoch 166 iteration100, G Loss: 193.28147888183594, D Loss: 5.706758485974944e-16, alpha: 0.018706509954354522
# OUTTTT
# OUTTTT
# Saving content.
# epoch 167 iteration0, G Loss: 160.15872192382812, D Loss: 3.928391002116149e-15, alpha: 0.017636340339722723
# epoch 167 iteration100, G Loss: 81.12017059326172, D Loss: 1.099051232245074e-07, alpha: 0.017636340339722723
# OUTTTT
# OUTTTT
# Saving content.
# epoch 168 iteration0, G Loss: 466.5441589355469, D Loss: 1.5239068009874e-14, alpha: 0.016626356107881657
# epoch 168 iteration100, G Loss: 349.0485534667969, D Loss: 2.5597451675657412e-12, alpha: 0.016626356107881657
# OUTTTT
# OUTTTT
# Saving content.
# epoch 169 iteration0, G Loss: 325.10943603515625, D Loss: 1.7708865312202927e-14, alpha: 0.01567328806604862
# epoch 169 iteration100, G Loss: 105.9263687133789, D Loss: 8.296988198708277e-06, alpha: 0.01567328806604862
# OUTTTT
# OUTTTT
# Saving content.
# epoch 170 iteration0, G Loss: 257.53692626953125, D Loss: 3.0294004318374493e-17, alpha: 0.01477403169327307
# epoch 170 iteration100, G Loss: 324.1774597167969, D Loss: 6.595577417556342e-08, alpha: 0.01477403169327307
# OUTTTT
# OUTTTT
# Saving content.
# epoch 171 iteration0, G Loss: 196.43426513671875, D Loss: 7.3875252581956374e-09, alpha: 0.013925640306500453
# epoch 171 iteration100, G Loss: 323.3852233886719, D Loss: 1.3125264679232423e-15, alpha: 0.013925640306500453
# OUTTTT
# OUTTTT
# Saving content.
# epoch 172 iteration0, G Loss: 80.909912109375, D Loss: 6.1042046546936035, alpha: 0.013125318337102843
# epoch 172 iteration100, G Loss: 152.22137451171875, D Loss: 4.9788086471380666e-05, alpha: 0.013125318337102843
# OUTTTT
# OUTTTT
# Saving content.
# epoch 173 iteration0, G Loss: 206.55844116210938, D Loss: 2.8721748829112215e-13, alpha: 0.012370414740162317
# epoch 173 iteration100, G Loss: 141.969482421875, D Loss: 1.4103085019256945e-12, alpha: 0.012370414740162317
# OUTTTT
# OUTTTT
# Saving content.
# epoch 174 iteration0, G Loss: 197.76161193847656, D Loss: 2.6089304583365447e-07, alpha: 0.011658416554833018
# epoch 174 iteration100, G Loss: 190.6017608642578, D Loss: 1.219569556454303e-09, alpha: 0.011658416554833018
# OUTTTT
# OUTTTT
# Saving content.
# epoch 175 iteration0, G Loss: 121.68233489990234, D Loss: 2.959012479486489e-10, alpha: 0.010986942630593188
# epoch 175 iteration100, G Loss: 467.5693054199219, D Loss: 5.540988028353699e-23, alpha: 0.010986942630593188
# OUTTTT
# OUTTTT
# Saving content.
# epoch 176 iteration0, G Loss: 466.5466003417969, D Loss: 2.1498012145534047e-21, alpha: 0.0103537375310917
# epoch 176 iteration100, G Loss: 576.3577880859375, D Loss: 1.6330403470324805e-16, alpha: 0.0103537375310917
# OUTTTT
# OUTTTT
# Saving content.
# epoch 177 iteration0, G Loss: 466.93865966796875, D Loss: 8.00492349272916e-14, alpha: 0.009756665624551242
# epoch 177 iteration100, G Loss: 112.306640625, D Loss: 6.701744194315129e-13, alpha: 0.009756665624551242
# OUTTTT
# OUTTTT
# Saving content.
# epoch 178 iteration0, G Loss: 349.98651123046875, D Loss: 7.542803733361946e-22, alpha: 0.00919370536728803
# epoch 178 iteration100, G Loss: 190.5853271484375, D Loss: 7.3422413982005e-12, alpha: 0.00919370536728803
# OUTTTT
# OUTTTT
# Saving content.
# epoch 179 iteration0, G Loss: 266.2350158691406, D Loss: 6.114839924033021e-24, alpha: 0.008662943784813137
# epoch 179 iteration100, G Loss: 218.92498779296875, D Loss: 3.375027094092227e-30, alpha: 0.008662943784813137
# OUTTTT
# OUTTTT
# Saving content.
# epoch 180 iteration0, G Loss: 99.56784057617188, D Loss: 3.4209699328932705e-16, alpha: 0.008162571153159881
# epoch 180 iteration100, G Loss: 297.3490295410156, D Loss: 1.6784810176747136e-15, alpha: 0.008162571153159881
# OUTTTT
# OUTTTT
# Saving content.
# epoch 181 iteration0, G Loss: 210.4611053466797, D Loss: 6.785693645477295, alpha: 0.007690875881508297
# epoch 181 iteration100, G Loss: 204.99864196777344, D Loss: 2.1437047337258264e-07, alpha: 0.007690875881508297
# OUTTTT
# OUTTTT
# Saving content.
# epoch 182 iteration0, G Loss: 333.6776428222656, D Loss: 3.038632101493022e-08, alpha: 0.007246239595831483
# epoch 182 iteration100, G Loss: 254.30877685546875, D Loss: 5.363554392290304e-11, alpha: 0.007246239595831483
# OUTTTT
# OUTTTT
# Saving content.
# epoch 183 iteration0, G Loss: 248.2776641845703, D Loss: 3.222431210758714e-09, alpha: 0.006827132422138282
# epoch 183 iteration100, G Loss: 238.17608642578125, D Loss: 1.2315328756784538e-09, alpha: 0.006827132422138282
# OUTTTT
# OUTTTT
# Saving content.
# epoch 184 iteration0, G Loss: 104.58749389648438, D Loss: 2.8834113763309688e-08, alpha: 0.006432108466918773
# epoch 184 iteration100, G Loss: 113.07240295410156, D Loss: 1.3272919430207253e-09, alpha: 0.006432108466918773
# OUTTTT
# OUTTTT
# Saving content.
# epoch 185 iteration0, G Loss: 99.18523406982422, D Loss: 9.788970036037764e-14, alpha: 0.006059801491584249
# epoch 185 iteration100, G Loss: 326.19158935546875, D Loss: 2.605878186845434e-12, alpha: 0.006059801491584249
# OUTTTT
# OUTTTT
# Saving content.
# epoch 186 iteration0, G Loss: 108.95198059082031, D Loss: 2.594239545405941e-10, alpha: 0.005708920777023452
# epoch 186 iteration100, G Loss: 78.15106964111328, D Loss: 4.676819997939674e-08, alpha: 0.005708920777023452
# OUTTTT
# OUTTTT
# Saving content.
# epoch 187 iteration0, G Loss: 194.90933227539062, D Loss: 3.7518474438336114e-11, alpha: 0.005378247173848605
# epoch 187 iteration100, G Loss: 127.58055114746094, D Loss: 1.0674959029218036e-19, alpha: 0.005378247173848605
# OUTTTT
# OUTTTT
# Saving content.
# epoch 188 iteration0, G Loss: 363.0785217285156, D Loss: 2.0108004150642955e-09, alpha: 0.005066629333466244
# epoch 188 iteration100, G Loss: 162.22549438476562, D Loss: 5.484308575784652e-16, alpha: 0.005066629333466244
# OUTTTT
# OUTTTT
# Saving content.
# epoch 189 iteration0, G Loss: 233.47262573242188, D Loss: 7.707353100484436e-21, alpha: 0.004772980114763237
# epoch 189 iteration100, G Loss: 288.2169494628906, D Loss: 5.0778526692041835e-17, alpha: 0.004772980114763237
# OUTTTT
# OUTTTT
# Saving content.
# epoch 190 iteration0, G Loss: 309.3503112792969, D Loss: 6.290026277611105e-08, alpha: 0.004496273160941144
# epoch 190 iteration100, G Loss: 78.59786987304688, D Loss: 8.399070793529972e-06, alpha: 0.004496273160941144
# OUTTTT
# OUTTTT
# Saving content.
# epoch 191 iteration0, G Loss: 49.45901870727539, D Loss: 4.049487642987515e-07, alpha: 0.004235539640843444
# epoch 191 iteration100, G Loss: 233.85008239746094, D Loss: 7.043993752002542e-13, alpha: 0.004235539640843444
# OUTTTT
# OUTTTT
# Saving content.
# epoch 192 iteration0, G Loss: 277.4385681152344, D Loss: 8.082380294799805, alpha: 0.003989865148994021
# epoch 192 iteration100, G Loss: 211.7371063232422, D Loss: 2.1791736344312085e-06, alpha: 0.003989865148994021
# OUTTTT
# OUTTTT
# Saving content.
# epoch 193 iteration0, G Loss: 420.2119445800781, D Loss: 4.66294999500318e-21, alpha: 0.003758386758500709
# epoch 193 iteration100, G Loss: 145.19085693359375, D Loss: 9.335230555004215e-19, alpha: 0.003758386758500709
# OUTTTT
# OUTTTT
# Saving content.
# epoch 194 iteration0, G Loss: 291.2500915527344, D Loss: 1.299871352329523e-23, alpha: 0.003540290220946485
# epoch 194 iteration100, G Loss: 227.44017028808594, D Loss: 5.790521230848968e-19, alpha: 0.003540290220946485
# OUTTTT
# OUTTTT
# Saving content.
# epoch 195 iteration0, G Loss: 452.74609375, D Loss: 5.019664629161806e-14, alpha: 0.003334807307413312
# epoch 195 iteration100, G Loss: 386.9704895019531, D Loss: 5.238823815524835e-19, alpha: 0.003334807307413312
# OUTTTT
# OUTTTT
# Saving content.
# epoch 196 iteration0, G Loss: 395.8311767578125, D Loss: 1.342958661464161e-30, alpha: 0.003141213284829414
# epoch 196 iteration100, G Loss: 315.6435241699219, D Loss: 0.004932713229209185, alpha: 0.003141213284829414
# OUTTTT
# OUTTTT
# Saving content.
# epoch 197 iteration0, G Loss: 303.77935791015625, D Loss: 2.35208462542923e-14, alpha: 0.0029588245219072107
# epoch 197 iteration100, G Loss: 167.41802978515625, D Loss: 1.1204980297759252e-22, alpha: 0.0029588245219072107
# OUTTTT
# OUTTTT
# Saving content.
# epoch 198 iteration0, G Loss: 210.63790893554688, D Loss: 1.0513531881419457e-23, alpha: 0.002786996219042215
# epoch 198 iteration100, G Loss: 205.7816162109375, D Loss: 5.9384259287753594e-08, alpha: 0.002786996219042215
# OUTTTT
# OUTTTT
# Saving content.
# epoch 199 iteration0, G Loss: 250.9246368408203, D Loss: 9.475687277199236e-15, alpha: 0.002625120256660174
# epoch 199 iteration100, G Loss: 596.7132568359375, D Loss: 8.351442045648758e-16, alpha: 0.002625120256660174
# OUTTTT
# OUTTTT
# Saving content.
# epoch 200 iteration0, G Loss: 748.2258911132812, D Loss: 3.9058843176210877e-17, alpha: 0.002472623156634657
# epoch 200 iteration100, G Loss: 76.86409759521484, D Loss: 1.2903949198062037e-07, alpha: 0.002472623156634657
# OUTTTT
# OUTTTT
# Saving content.

# %%
import os
from PIL import Image
import numpy as np
import torch
from torchvision import transforms

# データ変換（リサイズとTensorに変換）
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.ToTensor(),
])

def load_images_from_dir(data_dir, extensions=('.png', '.jpg', '.jpeg')):
    """
    指定されたディレクトリから画像を読み込む。
    
    Args:
        data_dir (str): 画像ディレクトリのパス
        extensions (tuple): 読み込みたい画像の拡張子のタプル
        
    Returns:
        List[torch.Tensor]: 画像をTensorに変換して返すリスト
    """
    if not os.path.exists(data_dir):
        raise FileNotFoundError(f"指定されたディレクトリが存在しません: {data_dir}")
    
    all_images = []
    
    with os.scandir(data_dir) as entries:
        for entry in entries:
            if entry.is_file() and entry.name.lower().endswith(extensions):
                img_path = entry.path
                try:
                    image = Image.open(img_path)
                    image = transform(image)
                    all_images.append(image)
                except Exception as e:
                    print(f"画像の読み込みに失敗しました: {img_path}, エラー: {e}")
    
    if len(all_images) == 0:
        raise ValueError("画像が見つかりませんでした。")

    return all_images

def calculate_mean_std(images):
    """
    画像のリストからチャンネルごとの平均と分散を計算する。
    
    Args:
        images (List[torch.Tensor]): 画像のTensorリスト
    
    Returns:
        (torch.Tensor, torch.Tensor): チャンネルごとの平均と標準偏差
    """
    all_images_tensor = torch.stack(images)
    mean = torch.mean(all_images_tensor, dim=[0, 2, 3])
    std = torch.std(all_images_tensor, dim=[0, 2, 3])
    return mean, std

# 画像ディレクトリ
data_dir = 'data/afhq/train/cat'

# 画像の読み込み
all_images = load_images_from_dir(data_dir)

# 平均と分散の計算
mean, std = calculate_mean_std(all_images)

print(f'平均: {mean}')
print(f'分散: {std ** 2}')
# Out:
# 平均: tensor([0.4990, 0.4567, 0.4067])
# 分散: tensor([0.0639, 0.0611, 0.0644])

# %%
afhq cat
size 512
平均: tensor([0.4985, 0.4562, 0.4062])
分散: tensor([0.0666, 0.0638, 0.0671])

size 256
平均: tensor([0.4990, 0.4567, 0.4067])
分散: tensor([0.0639, 0.0611, 0.0644])

size 128
平均: tensor([0.4986, 0.4563, 0.4064])
分散: tensor([0.0625, 0.0597, 0.0630])

平均：0.4987, 0.4564, 0.4064
分散：0.0643, 0.0615, 0.0648
